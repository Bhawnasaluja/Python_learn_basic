# %%
a=int(input('Enter first number:'))
b=int(input('Enter second number:'))
add=a+b
sub=a-b
mul=a*b
div=round(a/b)
print(f"Addition:{add}\n Subtraction:{sub}\n Multiplication:{mul}\n Division:{div}")
# Out:
# Enter first number: 34
# Enter second number: 3
# Addition:37
#  Subtraction:31
#  Multiplication:102
#  Division:11

# %%
first=input('Enter your first name:')
last=input('Enter your last name:')
full=first+" "+last
print(f"Hello ,{full}! Welcome to the python program")
# Out:
# Enter your first name: Neha
# Enter your last name: Aggarwal
# Hello ,Neha Aggarwal! Welcome to the python program
